# %%
import pandas as pd

# %%
df = pd.read_csv('./new-data/listings.csv')

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20240622024514   2024-06-22
# 1   5506   https://www.airbnb.com/rooms/5506  20240622024514   2024-06-22
# 2   6695   https://www.airbnb.com/rooms/6695  20240622024514   2024-06-22
# 3   8789   https://www.airbnb.com/rooms/8789  20240622024514   2024-06-22
# 4  10811  https://www.airbnb.com/rooms/10811  20240622024514   2024-06-22
#
#         source                                              name  \
# 0  city scrape                         HARBORSIDE-Walk to subway
# 1  city scrape    ** Fort Hill Inn Private! Minutes to center!**
# 2  city scrape     Fort Hill Inn *Sunny* 1 bedroom, condo duplex
# 3  city scrape               Curved Glass Studio/1bd facing Park
# 4  city scrape  Back Bay Apt Studio-3 blocks to Pru center & "T"
#
#                                                                                            description  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
hosts_by_properties = df.groupby('host_id')['id'].count()

# %%
hosts_by_properties.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1410 entries, 4804 to 583290692
# Series name: id
# Non-Null Count  Dtype
# --------------  -----
# 1410 non-null   int64
# dtypes: int64(1)
# memory usage: 22.0 KB

# %%
hosts_by_properties.sort_values(ascending=False)
# Out:
# host_id
# 107434423    379
# 297860058    154
# 22348222      87
# 382451810     74
# 331225367     72
#             ...
# 38403389       1
# 38381764       1
# 38302832       1
# 38284667       1
# 583290692      1
# Name: id, Length: 1410, dtype: int64

# %%
HOST_ID = 22348222

managed_listings = df[df['host_id']==HOST_ID]

managed_listings.to_csv('./data/maverick-listings.csv',index=False)

# %%
managed_listings.head()
# Out:
#           id                           listing_url       scrape_id  \
# 157  4461613  https://www.airbnb.com/rooms/4461613  20240622024514
# 158  4461846  https://www.airbnb.com/rooms/4461846  20240622024514
# 159  4461901  https://www.airbnb.com/rooms/4461901  20240622024514
# 160  4500409  https://www.airbnb.com/rooms/4500409  20240622024514
# 169  4623114  https://www.airbnb.com/rooms/4623114  20240622024514
#
#     last_scraped       source  \
# 157   2024-06-22  city scrape
# 158   2024-06-22  city scrape
# 159   2024-06-22  city scrape
# 160   2024-06-22  city scrape
# 169   2024-06-22  city scrape
#
#                                                    name  \
# 157  Comfy Beacon Hill Studio Great for Work Travel #13
# 158        South End Studio Perfect for Work Travel #36
# 159         Stylish Downtown Studio in the SouthEnd, #8
# 160       Stylish Studio in Back Bay, on Newbury St; #1
# 169        South End Studio Perfect for Work Travel #46
#
# ...

# %%
columns = ['name', 'description', 'neighbourhood', 'host_name', 'review_scores_rating', 'picture_url', 'id']

ml = managed_listings[columns]

# %%
pd.set_option('display.max_colwidth', 100)
ml.head()
# Out:
#                                                    name  \
# 157  Comfy Beacon Hill Studio Great for Work Travel #13
# 158        South End Studio Perfect for Work Travel #36
# 159         Stylish Downtown Studio in the SouthEnd, #8
# 160       Stylish Studio in Back Bay, on Newbury St; #1
# 169        South End Studio Perfect for Work Travel #46
#
#                                                                                              description  \
# 157  Our stylish and comfortable studio offers the luxury of home furnishings with the accessibility ...
# 158  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
# 159  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
# 160  Our comfortable studio is centrally located on Boston's most Chic and Lively street. Newbury Str...
# 169  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
#
# ...

# %%
ml.head()
# Out:
#                                                    name  \
# 157  Comfy Beacon Hill Studio Great for Work Travel #13
# 158        South End Studio Perfect for Work Travel #36
# 159         Stylish Downtown Studio in the SouthEnd, #8
# 160       Stylish Studio in Back Bay, on Newbury St; #1
# 169        South End Studio Perfect for Work Travel #46
#
#                                                                                              description  \
# 157  Our stylish and comfortable studio offers the luxury of home furnishings with the accessibility ...
# 158  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
# 159  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
# 160  Our comfortable studio is centrally located on Boston's most Chic and Lively street. Newbury Str...
# 169  The unit is stylishly designed for comfort, value and convenience. Centrally located on the line...
#
# ...

# %%
ml.neighbourhood.unique()
# Out:
# array(['Neighborhood highlights', nan], dtype=object)

# %%
listing_ids = list(ml.id.unique())

# %%
reviews = pd.read_csv('./new-data/reviews.csv')

# %%
reviews = reviews[reviews['listing_id'].isin(listing_ids)]

# %%
reviews['date'] = pd.to_datetime(reviews['date'])

# %%
reviews = reviews[reviews['date'] >= '2024-01-01']

# %%
len(reviews)
# Out:
# 1127

# %%
reviews.to_csv('./data/maverick-reviews-2024.csv', index=False)

# %%
ml.columns
# Out:
# Index(['name', 'description', 'neighbourhood', 'host_name',
#        'review_scores_rating', 'picture_url', 'id'],
#       dtype='object')

# %%
reviews['listing_id'].value_counts()
# Out:
# listing_id
# 7728499                358
# 7832890                346
# 7475573                324
# 5769127                310
# 7635616                303
#                       ...
# 970254183341401847      12
# 970254498756780127      11
# 970253349165956159      11
# 970255334813267456       9
# 1168848022411382766      2
# Name: count, Length: 87, dtype: int64

# %%
reviews_listing = reviews[reviews['listing_id']==7728499]

# %%
reviews_listing.tail(20)
# Out:
#        listing_id                   id        date  reviewer_id reviewer_name  \
# 39228     7728499  1059521521066760223  2024-01-01     89376641         Irene
# 39229     7728499  1066056984391680729  2024-01-10    414915279       Kathryn
# 39230     7728499  1067472936424028443  2024-01-12     12765332      Danielle
# 39231     7728499  1103657856451057291  2024-03-02    171298842         Katie
# 39232     7728499  1106630372726701657  2024-03-06    362075061         Abram
# 39233     7728499  1107383734395140631  2024-03-07      2633192       Shannon
# 39234     7728499  1120372077688040774  2024-03-25    509780948        Sherry
# 39235     7728499  1126898370048687884  2024-04-03     30505463         Brady
# 39236     7728499  1129829936025517618  2024-04-07    473093096          Kurt
# 39237     7728499  1131206756304292493  2024-04-09    176884301        Kyanna
# 39238     7728499  1132694783370626606  2024-04-11    153348991      Vladimír
# ...

# %%
ml
# Out:
#                                                     name  \
# 157   Comfy Beacon Hill Studio Great for Work Travel #13
# 158         South End Studio Perfect for Work Travel #36
# 159          Stylish Downtown Studio in the SouthEnd, #8
# 160        Stylish Studio in Back Bay, on Newbury St; #1
# 169         South End Studio Perfect for Work Travel #46
# ...                                                  ...
# 3406                 Modern Suite in Fenway Neighborhood
# 3429  Stylish Studio the Fenway Neighborhood - Unit #106
# 3785   Stylish Hotel Room in Boston's Fenway - Unit #104
# 3786   Stylish Hotel Room in Boston's Fenway - Unit #107
# 4264        Charming & Stylish Studio on Beacon Hill; #5
#
#                                                                                               description  \
# 157   Our stylish and comfortable studio offers the luxury of home furnishings with the accessibility ...
# ...
